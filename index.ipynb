# %% [markdown]
# # Scrubbing and Cleaning Data - Lab
#
# ## Introduction
#
# In the previous labs, you joined the data from our separate files into a single DataFrame.  In this lab, you'll scrub the data to get it ready for exploration and modeling!
#
# ## Objectives
#
# You will be able to:
#
# * Cast columns to the appropriate data types
# * Identify and deal with null values appropriately
# * Remove unnecessary columns
# * Understand how to normalize data
#
#
# ## Getting Started
#
# You'll find the resulting dataset from your work in the _Obtaining Data_ Lab stored within the file `'Lego_data_merged.csv'`.
#
# In the cells below:
#
# * Import `pandas` and set the standard alias.
# * Import `numpy` and set the standard alias.
# * Import `matplotlib.pyplot` and set the standard alias.
# * Import `seaborn` and set the alias `sns` (this is the standard alias for seaborn).
# * Use the ipython magic command to set all matplotlib visualizations to display inline in the notebook.
# * Load the dataset stored in the `'Lego_data_merged.csv'` file into a DataFrame, `df`.
# * Inspect the head of the DataFrame to ensure everything loaded correctly.

# %%
# Import statements go here
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Now, load in the dataset and inspect the head to make sure everything loaded correctly
df = pd.read_csv('Lego_data_merged.csv')
df.head()
# Out:
#    prod_id  ages  piece_count                        set_name  \
# 0    75823  6-12          277           Bird Island Egg Heist
# 1    75822  6-12          168              Piggy Plane Attack
# 2    75821  6-12           74                Piggy Car Escape
# 3    21030   12+         1032  United States Capitol Building
# 4    21035   12+          744   Solomon R. Guggenheim Museum®
#
#                                            prod_desc  \
# 0  Catapult into action and take back the eggs fr...
# 1  Launch a flying attack and rescue the eggs fro...
# 2  Chase the piggy with lightning-fast Chuck and ...
# 3  Explore the architecture of the United States ...
# 4  Recreate the Solomon R. Guggenheim Museum® wit...
#
#                                       prod_long_desc    theme_name country  \
# 0  Use the staircase catapult to launch Red into ...  Angry Birds™      US
# 1  Pilot Pig has taken off from Bird Island with ...  Angry Birds™      US
# 2  Pitch speedy bird Chuck against the Piggy Car....  Angry Birds™      US
# 3  Discover the architectural secrets of the icon...  Architecture      US
# 4  Discover the architectural secrets of Frank Ll...  Architecture      US
#
#   list_price  num_reviews  play_star_rating review_difficulty  star_rating  \
# 0     $29.99          2.0               4.0           Average          4.5
# 1     $19.99          2.0               4.0              Easy          5.0
# 2     $12.99         11.0               4.3              Easy          4.3
# 3     $99.99         23.0               3.6           Average          4.6
# 4     $79.99         14.0               3.2       Challenging          4.6
#
#    val_star_rating
# 0              4.0
# 1              4.0
# 2              4.1
# 3              4.3
# 4              4.1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10870 entries, 0 to 10869
# Data columns (total 14 columns):
# prod_id              10870 non-null int64
# ages                 10870 non-null object
# piece_count          10870 non-null int64
# set_name             10870 non-null object
# prod_desc            10512 non-null object
# prod_long_desc       10870 non-null object
# theme_name           10870 non-null object
# country              10870 non-null object
# list_price           10870 non-null object
# num_reviews          9449 non-null float64
# play_star_rating     9321 non-null float64
# review_difficulty    9104 non-null object
# star_rating          9449 non-null float64
# val_star_rating      9301 non-null float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Starting our Data Cleaning
#
# To start, you'll deal with the most obvious issue: data features with the wrong data encoding.
#
# ### Checking Data Types
#
# In the cell below, use the appropriate method to check the data type of each column.

# %% [markdown]
# Now, investigate some of the unique values inside of the `list_price` column.

# %%
# Your code here
df['list_price'] = df['list_price'].str[1:].astype(float)

# %% [markdown]
# ### Numerical Data Stored as Strings
#
# A common issue to check for at this stage is numeric columns that have accidentally been encoded as strings. For example, you should notice that the `list_price` column above is currently formatted as a string and contains a proceeding '$'. Remove this and convert the remaining number to a `float` so that you can later model this value. After all, your primary task is to generate model to predict the price.
#
# > Note: While the data spans a multitude of countries, assume for now that all prices have been standardized to USD.

# %%
# Your code here

# %% [markdown]
# ### Detecting and Dealing With Null Values
#
# Next, it's time to check for null values. How to deal with the null values will be determined by the columns containing them, and how many null values exist in each.
#
# In the cell below, get a count of how many null values exist in each column in the DataFrame.

# %%
# Your code here
df.isna().sum()
# Out:
# prod_id                 0
# ages                    0
# piece_count             0
# set_name                0
# prod_desc             358
# prod_long_desc          0
# theme_name              0
# country                 0
# list_price              0
# num_reviews          1421
# play_star_rating     1549
# review_difficulty    1766
# star_rating          1421
# val_star_rating      1569
# dtype: int64

# %% [markdown]
# Now, get some descriptive statistics for each of the columns. You want to see where the minimum and maximum values lie.

# %%
# Your code here

# %% [markdown]
# Now that you have a bit more of a understanding of each of these features you can make an informed decision about the best strategy for dealing with the various null values.
#
# Some common strategies for filling null values include:
# * Using the mean of the feature
# * Using the median of the feature
# * Inserting a random value from a normal distribution with the mean and std of the feature
# * Binning
#
# Given that most of the features with null values concern user reviews of the lego set, it is reasonable to wonder whether there is strong correlation between these features in the first place. Before proceeding, take a minute to investigate this hypothesis.

# %%
# Investigate whether multicollinearity exists between the review features 
# (num_reviews, play_star_rating, star_rating, val_star_rating)
df2 = df.loc[:,['play_star_rating','num_reviews','star_rating','val_star_rating']]

# %%
df2.corr()
# Out:
#                   play_star_rating  num_reviews  star_rating  val_star_rating
# play_star_rating          1.000000    -0.060884     0.619246         0.484341
# num_reviews              -0.060884     1.000000     0.004541         0.026664
# star_rating               0.619246     0.004541     1.000000         0.731538
# val_star_rating           0.484341     0.026664     0.731538         1.000000

# %% [markdown]
# Note that there is substantial correlation between the `play_star_rating`, `star_rating` and `val_star_rating`. While this could lead to multicollinearity in your eventual regression model, it is too early to clearly determine this at this point. Remember that multicollinearity is a relationship between 3 or more variables while correlation simply investigates the relationship between two variables.
#
# Additionally, these relationships provide an alternative method for imputing missing values: since they appear to be correlated, you could use these features to help impute missing values in the others features. For example, if you are missing the `star_rating` for a particular row but have the `val_star_rating` for that same entry, it seems reasonable to assume that it is a good estimate for the missing `star_rating` value as they are highly correlated. That said, doing so does come with risks; indeed you would be further increasing the correlation between these features which could further provoke multicollinearity in the final model.
#
# Investigate if you could use one of the other star rating features when one is missing. How many rows have one of `play_star_rating`, `star_rating` and `val_star_rating` missing, but not all three.

# %%
df.isna().sum()
# Out:
# prod_id                 0
# ages                    0
# piece_count             0
# set_name                0
# prod_desc             358
# prod_long_desc          0
# theme_name              0
# country                 0
# list_price              0
# num_reviews          1421
# play_star_rating     1549
# review_difficulty    1766
# star_rating          1421
# val_star_rating      1569
# dtype: int64

# %%
# Your code here
df_3_null = df[(df['play_star_rating'].isna())&(df['star_rating'].isna())&(df['val_star_rating'].isna())]
# Number missing all three: 1421
df_3_null.shape
# Out:
# (1421, 14)

# %% [markdown]
# Well, it seems like when one is missing, the other two are also apt to be missing. While this has been a bit of an extended investigation, simply go ahead and fill the missing values with that feature's median. Fill in the missing values of `review_difficulty` feature  with string `'unknown'`.

# %%
# Your code here
df['review_difficulty'].fillna('unknown',inplace=True)
df['play_star_rating'].fillna(df['play_star_rating'].median(),inplace=True)
df['star_rating'].fillna(df['star_rating'].median(),inplace=True)
df['val_star_rating'].fillna(df['val_star_rating'].median(),inplace=True)

# %% [markdown]
# ## Normalizing the Data
#
# Now, you'll need to convert all of our numeric columns to the same scale by **_normalizing_** our dataset.  Recall that you normalize a dataset by converting each numeric value to it's corresponding z-score for the column, which is obtained by subtracting the column's mean and then dividing by the column's standard deviation for every value.
#
#
# In the cell below:
#
# * Normalize the numeric X features by subtracting the column mean and dividing by the column standard deviation.
# (Don't bother to normalize the `list_price` as this is the feature you will be predicting.)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10870 entries, 0 to 10869
# Data columns (total 14 columns):
# prod_id              10870 non-null int64
# ages                 10870 non-null object
# piece_count          10870 non-null int64
# set_name             10870 non-null object
# prod_desc            10512 non-null object
# prod_long_desc       10870 non-null object
# theme_name           10870 non-null object
# country              10870 non-null object
# list_price           10870 non-null float64
# num_reviews          9449 non-null float64
# play_star_rating     10870 non-null float64
# review_difficulty    10870 non-null object
# star_rating          10870 non-null float64
# val_star_rating      10870 non-null float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 1.2+ MB

# %%
# Your code here
for col in df.columns:
    if df[col].dtype == 'float64' or df[col].dtype == 'int64':
        df[col] = df[col].apply(lambda x: (x-df[col].mean())/df[col].std())

# %%
df
# Out:
#         prod_id   ages  piece_count                         set_name  \
# 0      0.080665   6-12    -0.273020            Bird Island Egg Heist
# 1      0.080660   6-12    -0.404154               Piggy Plane Attack
# 2      0.080654   6-12    -0.517242                 Piggy Car Escape
# 3     -0.234892    12+     0.635296   United States Capitol Building
# 4     -0.234863    12+     0.288812    Solomon R. Guggenheim Museum®
# 5     -0.234840    12+     0.111962                         Shanghai
# 6     -0.234903    12+     0.113165                    New York City
# 7     -0.234897    12+     0.332123                Buckingham Palace
# 8     -0.234869    12+    -0.043234                           London
# 9     -0.234874    12+    -0.072108                          Chicago
# 10    -0.234857    12+    -0.141885                  Arc de Triomphe
# 11    -0.234955    12+    -0.220085                 The Eiffel Tower
# 12    -0.234880    12+    -0.171962                           Sydney
# 13    -0.257519   7-12     0.412728           BOOST Creative Toolbox
# 14    -0.116445    10+     0.245502                      Go Brick Me
# 15    -0.116347    10+    -0.324751                      Owen & Blue
# 16    -0.116353    10+    -0.413778         Mr. Incredible & Frozone
# 17    -0.116376    10+    -0.427012                       Chewbacca™
# 18    -0.116381    10+    -0.436637                        Han Solo™
# 19    -0.116404    10+    -0.484759                    Iron Man MK50
# 20    -0.116399    10+    -0.479947                           Thanos
# 21    -0.116393    10+    -0.470322                        Star-Lord
# 22    -0.116387    10+    -0.442652                           Gamora
# 23    -0.117090    10+    -0.496790                             Finn
# 24    -0.124087    10+    -0.437840                  Valentine's Bee
# 25    -0.116433    10+    -0.434230                    Wonder Woman™
# 26    -0.116439    10+    -0.459495                       The Flash™
# 27    -0.116410    10+    -0.449870                        Kylo Ren™
# 28    -0.116416    10+    -0.463104                              Rey
# 29    -0.116427    10+    -0.443855                         Aquaman™
# ...         ...    ...          ...                              ...
# 10840 -0.113680  10-16     0.602813                        Rally Car
# 10841 -0.113749   9-16    -0.161134                 RC Tracked Racer
# 10842 -0.113732  10-16     0.714698           Airport Rescue Vehicle
# 10843 -0.113686   9-16     0.620859                       Hovercraft
# 10844 -0.113761  10-16     0.119180          BMW R 1200 GS Adventure
# 10845 -0.113767   8-14     0.152866                   Container Yard
# 10846 -0.113692   9-16     0.010904                  First Responder
# 10847 -0.308245   9-16    -0.594238  LEGO® Power Functions Motor Set
# 10848 -0.113698   8-14    -0.209257                     Racing Yacht
# 10849 -0.113709   7-14    -0.443855                           WHACK!
# 10850 -0.113703   7-14    -0.439043                            BASH!
# 10851 -0.113784   7-14    -0.435434                      Stunt Truck
# 10852 -0.113778   8-14    -0.167150                    Roadwork Crew
# 10853 -0.113790   7-14    -0.437840                       Stunt Bike
# 10854 -0.113796   8-14    -0.366859            Ultralight Helicopter
# 10855 -0.113715   8-14    -0.400545                  Dozer Compactor
# 10856 -0.113640   7-14    -0.394529                      Hook Loader
# 10857  0.052383  12-16     1.352323                    Arkham Asylum
# 10858  0.052411  10-16     1.145396           The Ultimate Batmobile
# 10859  0.052365   8-14     0.653342                 Batcave Break-in
# 10860  0.052406   9-14     0.660560                      The Batwing
# 10861  0.052342   8-14     0.092713                    The Batmobile
# 10862  0.052348   8-14    -0.085341    The Joker™ Notorious Lowrider
# 10863  0.052394   8-14    -0.165947         Bane™ Toxic Truck Attack
# 10864  0.052377   8-14    -0.239334       The Penguin™ Arctic Roller
# 10865  0.052331   7-14    -0.300690        The Riddler™ Riddle Racer
# 10866  0.052371   7-14    -0.360843      Scarecrow™ Special Delivery
# 10867  0.052319   7-14    -0.364453           Mr. Freeze™ Ice Attack
# 10868  0.052388   6-12    -0.436637      Scarecrow™ Fearful Face-off
# 10869  0.052313   6-12    -0.457089        The Joker™ Balloon Escape
#
#                                                prod_desc  \
# 0      Catapult into action and take back the eggs fr...
# 1      Launch a flying attack and rescue the eggs fro...
# 2      Chase the piggy with lightning-fast Chuck and ...
# 3      Explore the architecture of the United States ...
# 4      Recreate the Solomon R. Guggenheim Museum® wit...
# 5      Celebrate Shanghai with this LEGO® Architectur...
# 6      Celebrate New York City with this LEGO® Archit...
# 7      Recreate Buckingham Palace with LEGO® Architec...
# 8      Celebrate London with this LEGO® Architecture ...
# 9      Celebrate Chicago with this LEGO® Architecture...
# 10       Experience the grandeur of the Arc de Triomphe!
# 11     Build your own LEGO® interpretation of the ico...
# 12     Celebrate Sydney with this LEGO® Architecture ...
# 13                   Bring your LEGO® creations to life!
# 14         Build a LEGO® BrickHeadz version of yourself!
# 15     Train a raptor with LEGO® BrickHeadz™ Owen and...
# 16     Join Mr. Incredible and Frozone for LEGO® Bric...
# 17     Growl like a Wookiee with a LEGO® BrickHeadz™ ...
# 18     Be a rogue with a LEGO® BrickHeadz™ constructi...
# 19     Save the universe with LEGO® BrickHeadz Iron M...
# 20     Feel the power of Infinity with LEGO® BrickHea...
# 21     Be a legendary outlaw with LEGO® BrickHeadz St...
# 22     Master the skills of a green-skinned assassin ...
# 23     Join the Resistance with a LEGO® BrickHeadz co...
# 24     Say “I love you” with a LEGO® BrickHeadz™ Vale...
# 25       Stand tall with LEGO® BrickHeadz Wonder Woman™!
# 26     Live life in the fast lane with LEGO® BrickHea...
# 27     Summon the dark side with a LEGO® BrickHeadz c...
# 28     Feel the Force with a LEGO® BrickHeadz constru...
# 29               Dive in with LEGO® BrickHeadz Aquaman™!
# ...                                                  ...
# 10840  Push the limits with the awesome LEGO® Technic...
# 10841  Travel over the toughest terrain with the RC T...
# 10842               Mobilize the Airport Rescue Vehicle!
# 10843  Transport supplies over land and sea with the ...
# 10844            Experience the BMW R 1200 GS Adventure!
# 10845  Grab, lift, load and deliver at the Container ...
# 10846  Explore iconic vehicle design with the First R...
# 10847  Motorize your LEGO® Technic creations with the...
# 10848  Put the wind in your sails with this amazing R...
# 10849  Get ready for high-speed action and impacts wi...
# 10850  Get ready for high-speed action and impacts wi...
# 10851  Fly off the ramp at high speed with the super-...
# 10852                         Call in the Roadwork Crew!
# 10853  Hit the ramp at high speed with the awesome St...
# 10854  Take to the skies with the Ultralight Helicopter!
# 10855              Call in the powerful Dozer Compactor!
# 10856  Collect and transport heavy cargo with the Hoo...
# 10857             Break into Arkham Asylum with Batman™!
# 10858  Divide the 4-in-1 Ultimate Batmobile and conqu...
# 10859   Protect the Batcave from The Penguin’s invasion!
# 10860   Patrol the sky above Gotham City in The Batwing!
# 10861  Pursue Man-Bat™ and the Kabuki Twins™ in the B...
# 10862  Team up with Batgirl™ to stop The Joker’s Noto...
# 10863     Protect Gotham City from Bane’s toxic attacks!
# 10864  Put the heat on The Penguin™ Arctic Roller wit...
# 10865  Battle with Batman™ against The Riddler™ and h...
# 10866  Help Batman™ to stop Scarecrow™ delivering a s...
# 10867  Protect the power plant from Mr. Freeze’s ice ...
# 10868  Power into the sky to stop Scarecrow’s fear ga...
# 10869             Help Batman™ stop The Joker™ escaping!
#
#                                           prod_long_desc  \
# 0      Use the staircase catapult to launch Red into ...
# 1      Pilot Pig has taken off from Bird Island with ...
# 2      Pitch speedy bird Chuck against the Piggy Car....
# 3      Discover the architectural secrets of the icon...
# 4      Discover the architectural secrets of Frank Ll...
# 5      Recreate Shanghai in China's blend of historic...
# 6      Celebrate the architectural diversity of New Y...
# 7      Build a LEGO® brick model of London's official...
# 8      Celebrate the architectural diversity of Londo...
# 9      Recreate Chicago’s blend of historical and mod...
# 10     Capture the architectural elegance of one of t...
# 11     Presenting the LEGO® Architecture interpretati...
# 12     Capture the architectural essence and splendor...
# 13     Take your LEGO® play to the next level with th...
# 14     Fuel your creativity by making a LEGO® BrickHe...
# 15     These LEGO® BrickHeadz™ 41614 Owen & Blue cons...
# 16     These LEGO® BrickHeadz™ 41613 Mr. Incredible &...
# 17     This LEGO® BrickHeadz™ 41609 Chewbacca is fun ...
# 18     This LEGO® BrickHeadz™ 41608 Han Solo is fun t...
# 19     This Iron Man MK50 LEGO® BrickHeadz constructi...
# 20     This Thanos LEGO® BrickHeadz construction char...
# 21     This Star-Lord LEGO® BrickHeadz construction c...
# 22     This Gamora LEGO® BrickHeadz construction char...
# 23     This LEGO® BrickHeadz construction character f...
# 24     Build your way to someone’s heart and say “Bee...
# 25     This Wonder Woman™ LEGO® BrickHeadz constructi...
# 26     The Flash™ LEGO® BrickHeadz construction chara...
# 27     This LEGO® BrickHeadz construction character f...
# 28     This LEGO® BrickHeadz construction character f...
# 29     This Aquaman™ LEGO® BrickHeadz construction ch...
# ...                                                  ...
# 10840  Discover awesome detail and design with this a...
# 10841  Spin, turn, clamber over obstacles and race at...
# 10842  Head for the runway with this authentic 2-in-1...
# 10843  Reach inhospitable areas with the LEGO® Techni...
# 10844  Explore the high-tech innovation of the BMW R ...
# 10845  Enjoy a rewarding build-and-play experience wi...
# 10846  Enjoy a rewarding build and play experience wi...
# 10847  Bring your LEGO® Technic models to life with t...
# 10848  Enter the world of water sports with this amaz...
# 10849  Experience the amazing power and acceleration ...
# 10850  Experience the amazing power and acceleration ...
# 10851  Perform amazing stunts with this high-speed LE...
# 10852  Get to work with this exciting, two-vehicle LE...
# 10853  Perform impressive stunts with this high-speed...
# 10854  Enjoy aerial adventures with this aerodynamic ...
# 10855  Capture the awesome power of a real-life dozer...
# 10856  Enjoy a rewarding build-and-play experience wi...
# 10857  Bust into Arkham Asylum with Batman™ and banis...
# 10858  Team up with THE LEGO® BATMAN MOVIE characters...
# 10859  Defend against The Penguin’s Duckmobile invasi...
# 10860  Fly high above Gotham City in the Batwing and ...
# 10861  Race through Gotham City in pursuit of Man-Bat...
# 10862  Join Batgirl’s pursuit of The Joker™ and Harle...
# 10863  Stop Bane™ and Mutant Leader’s toxic attacks w...
# 10864  Join Batman’s pursuit of The Penguin in THE LE...
# 10865  Take on four Super-Villains at once in THE LEG...
# 10866  Save Gotham City Energy Facility from a fear g...
# 10867  Help Batman™ defend the Gotham City Energy Fac...
# 10868  Team up with Batman™ to stop Scarecrow™ spread...
# 10869  Stage a face-off between The Joker™ and Batman...
#
#                    theme_name country  list_price  num_reviews  \
# 0                Angry Birds™      US   -0.394205    -0.414333
# 1                Angry Birds™      US   -0.499836    -0.414333
# 2                Angry Birds™      US   -0.573777    -0.178526
# 3                Architecture      US    0.345210     0.135885
# 4                Architecture      US    0.133949    -0.099923
# 5                Architecture      US   -0.077313    -0.283329
# 6                Architecture      US   -0.077313     0.502697
# 7                Architecture      US   -0.182943     0.162085
# 8                Architecture      US   -0.288574     0.135885
# 9                Architecture      US   -0.288574    -0.178526
# 10               Architecture      US   -0.288574    -0.099923
# 11               Architecture      US   -0.341389     0.921910
# 12               Architecture      US   -0.394205    -0.283329
# 13                      BOOST      US    0.978995     1.183919
# 14                 BrickHeadz      US   -0.394205    -0.126124
# 15                 BrickHeadz      US   -0.499836    -0.440534
# 16                 BrickHeadz      US   -0.499836    -0.440534
# 17                 BrickHeadz      US   -0.605466    -0.440534
# 18                 BrickHeadz      US   -0.605466    -0.440534
# 19                 BrickHeadz      US   -0.605466    -0.388133
# 20                 BrickHeadz      US   -0.605466    -0.414333
# 21                 BrickHeadz      US   -0.605466    -0.440534
# 22                 BrickHeadz      US   -0.605466    -0.440534
# 23                 BrickHeadz      US   -0.605466    -0.414333
# 24                 BrickHeadz      US   -0.605466    -0.283329
# 25                 BrickHeadz      US   -0.605466    -0.335731
# 26                 BrickHeadz      US   -0.605466    -0.388133
# 27                 BrickHeadz      US   -0.605466    -0.335731
# 28                 BrickHeadz      US   -0.605466    -0.388133
# 29                 BrickHeadz      US   -0.605466    -0.440534
# ...                       ...     ...         ...          ...
# 10840                 Technic      PT    0.577575    -0.257128
# 10841                 Technic      PT    0.448705     0.266889
# 10842                 Technic      PT    0.448705    -0.152325
# 10843                 Technic      PT    0.255401    -0.335731
# 10844                 Technic      PT   -0.002338    -0.152325
# 10845                 Technic      PT   -0.002338    -0.257128
# 10846                 Technic      PT   -0.131208    -0.440534
# 10847         Power Functions      PT   -0.247190     1.026714
# 10848                 Technic      PT   -0.324512    -0.335731
# 10849                 Technic      PT   -0.453381    -0.440534
# 10850                 Technic      PT   -0.453381    -0.414333
# 10851                 Technic      PT   -0.453381    -0.283329
# 10852                 Technic      PT   -0.453381    -0.204727
# 10853                 Technic      PT   -0.453381    -0.414333
# 10854                 Technic      PT   -0.492042    -0.230927
# 10855                 Technic      PT   -0.517816    -0.414333
# 10856                 Technic      PT   -0.569364    -0.414333
# 10857  THE LEGO® BATMAN MOVIE      PT    1.479661     0.057282
# 10858  THE LEGO® BATMAN MOVIE      PT    1.157487     0.004880
# 10859  THE LEGO® BATMAN MOVIE      PT    0.770879     0.135885
# 10860  THE LEGO® BATMAN MOVIE      PT    0.577575    -0.361932
# 10861  THE LEGO® BATMAN MOVIE      PT    0.126531     0.057282
# 10862  THE LEGO® BATMAN MOVIE      PT    0.023436     0.031081
# 10863  THE LEGO® BATMAN MOVIE      PT   -0.066773    -0.309530
# 10864  THE LEGO® BATMAN MOVIE      PT   -0.260077     0.162085
# 10865  THE LEGO® BATMAN MOVIE      PT   -0.260077     0.004880
# 10866  THE LEGO® BATMAN MOVIE      PT   -0.388947    -0.257128
# 10867  THE LEGO® BATMAN MOVIE      PT   -0.388947     0.031081
# 10868  THE LEGO® BATMAN MOVIE      PT   -0.517816    -0.283329
# 10869  THE LEGO® BATMAN MOVIE      PT   -0.517816     0.004880
#
#        play_star_rating review_difficulty  star_rating  val_star_rating
# 0             -0.655279           Average    -0.045687        -0.365010
# 1             -0.655279              Easy     0.990651        -0.365010
# 2             -0.132473              Easy    -0.460222        -0.204063
# 3             -1.352353           Average     0.161581         0.117830
# 4             -2.049427       Challenging     0.161581        -0.204063
# 5             -1.178084           Average     0.783383         0.278777
# 6             -1.178084           Average    -0.667489        -0.204063
# 7              0.041796           Average     0.368848         0.117830
# 8             -1.352353           Average     0.368848        -0.204063
# 9             -1.352353           Average     0.576116         0.439724
# 10            -0.481010           Average    -0.252954        -1.008797
# 11            -2.049427           Average     0.161581         0.278777
# 12            -0.306741              Easy     0.161581        -0.043117
# 13            -1.003816           Average    -2.325629        -1.169744
# 14             0.564601           Average     0.576116         0.922564
# 15            -2.397964              Easy     0.990651         1.244458
# 16             1.087407         Very Easy     0.990651         1.244458
# 17            -4.140649         Very Easy    -3.154699        -0.365010
# 18            -4.140649         Very Easy    -1.082024        -0.365010
# 19            -0.655279           Average     0.368848         0.439724
# 20            -2.397964              Easy     0.990651         1.244458
# 21             1.087407              Easy     0.990651         1.244458
# 22             0.216064           unknown     0.990651         0.117830
# 23            -2.397964              Easy    -0.045687        -0.365010
# 24            -2.049427              Easy     0.783383         0.761617
# 25             0.390333              Easy     0.990651         1.244458
# 26            -2.920769         Very Easy    -1.082024        -1.974478
# 27            -0.132473              Easy     0.990651         0.922564
# 28             0.216064              Easy     0.990651         0.439724
# 29            -5.883334         Very Easy    -1.082024        -1.974478
# ...                 ...               ...          ...              ...
# 10840         -0.481010           Average    -0.252954        -0.204063
# 10841          0.390333              Easy    -0.045687        -0.043117
# 10842         -0.655279           Average     0.576116         0.600671
# 10843         -1.003816           Average    -0.667489        -0.043117
# 10844         -0.306741           Average     0.368848         0.278777
# 10845          0.564601              Easy     0.576116         0.117830
# 10846          1.087407              Easy     0.990651        -0.365010
# 10847          0.390333              Easy    -0.045687        -0.525957
# 10848         -0.655279           Average     0.576116        -0.043117
# 10849          1.087407           unknown     0.990651         1.244458
# 10850          0.216064              Easy    -1.082024        -1.169744
# 10851          0.041796              Easy     0.368848         0.600671
# 10852          0.390333              Easy     0.576116         0.600671
# 10853          0.216064              Easy    -1.082024        -0.365010
# 10854         -0.132473              Easy     0.368848         0.922564
# 10855          1.087407       Challenging     0.990651         1.244458
# 10856          0.216064              Easy    -0.045687         0.439724
# 10857         -1.526621           Average    -1.496559        -1.491638
# 10858          0.390333           Average     0.161581         0.600671
# 10859          0.564601           Average     0.368848         0.117830
# 10860         -0.655279           Average    -1.082024        -0.686904
# 10861          0.390333           Average     0.576116         0.117830
# 10862          0.041796           Average     0.368848        -0.043117
# 10863         -1.178084           Average    -1.082024        -1.974478
# 10864          0.216064              Easy     0.576116         0.278777
# 10865         -0.306741              Easy    -0.667489         0.278777
# 10866         -0.481010           Average    -0.252954        -0.204063
# 10867         -0.481010              Easy     0.161581         0.278777
# 10868         -0.655279              Easy    -0.874757         0.278777
# 10869          0.216064              Easy     0.368848         0.600671
#
# [10870 rows x 14 columns]

# %% [markdown]
# ## Saving Your Results
#
# While you'll once again practice one-hot encoding as you would to preprocess data before fitting a model, saving such a reperesentation of the data will eat up additional disk space. After all, a categorical variable with 10 bins will be transformed to 10 seperate features when passed through `pd.get_dummies()`. As such, while further practice is worthwhile, save your DataFrame as is for now.

# %%
# Your code here
df.to_csv('df.csv')

# %% [markdown]
# ## One-Hot Encoding Categorical Columns
#
# As a final step, you'll need to deal with the categorical columns by **_one-hot encoding_** them into binary variables via the `pd.get_dummies()` function.
#
# When doing this, you may also need to subset the appropriate features to avoid encoding the wrong data. The `get_dummies()` function by default converts all columns with *object* or *category* dtype. However, you should always check the result of calling `get_dummies()` to ensure that only the categorical variables have been transformed. Consult the [documentation](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.get_dummies.html) for more details. If you are ever unsure of the data types, call the `.info()` method.
#
# In the cell below, subset to the appropriate predictive features and then use `pd.get_dummies()` to one-hot encode the dataset properly.

# %%
# Your code here
for col in df.columns:
    if df[col].dtype == 'object':
        pd.get_dummies(df,prefix=col,drop_first=True)

# %% [markdown]
# That's it! You've now successfully scrubbed your dataset -- you're now ready for data exploration and modeling!
#
# ## Summary
#
# In this lesson, you gained practice with data cleaning by:
#
# * Casting columns to the appropriate data types
# * Identifying and dealing with null values appropriately
# * Removing unnecessary columns
# * Checking for and dealing with multicollinearity
# * Normalizing your data
